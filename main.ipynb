# %%
# %reload_ext autoreload
# %autoreload 2

import torch
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
from torchvision import transforms as tfs
from torchvision import models
from torch import nn

import matplotlib.pyplot as plt
# %matplotlib inline

import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
# 是否使用GPU
use_gpu = False

# %%
# 数据增强
train_transform = tfs.Compose([
    # 训练集的数据预处理
    tfs.Resize([224, 224]),
    tfs.RandomHorizontalFlip(),
    tfs.RandomCrop(128),
    tfs.ToTensor(),
    tfs.Normalize([0.5,0.5,0.5], [0.5,0.5,0.5])
])

test_transform = tfs.Compose([
    tfs.Resize([224,224]),
#     tfs.RandomCrop(128),
    tfs.ToTensor(),
    tfs.Normalize([0.5,0.5,0.5], [0.5,0.5,0.5])
])

# %%
# 每一个batch的数据集数目
batch_size = 10

# %%
# 构建训练集和验证集
train_set = ImageFolder('./dataset/train', train_transform)
train_data = DataLoader(train_set, batch_size, shuffle=True, num_workers=2)

valid_set = ImageFolder('./dataset/valid', test_transform)
valid_data = DataLoader(valid_set, 2*batch_size, shuffle=False, num_workers=2)

# %%
train_set.class_to_idx
# Out:
# {'ads': 0, 'cheapjack': 1, 'litter': 2}

# %%
len(valid_data)
# Out:
# 7

# %%
try:
    if iter(train_data).next()[0].shape[0] == batch_size and \
    iter(valid_data).next()[0].shape[0] == 2*batch_size:
        print('Dataset is ready!')
    else:
        print('Not success, maybe the batch size is wrong')
except:
    print('not success, image transform is wrong!')
# Out:
# Dataset is ready!

# %%
# 构建模型
def get_model():
    model = models.resnet50(pretrained=True)
    model.fc = nn.Linear(2048, 3)
    return model

try:
    model = get_model()
    with torch.no_grad():
        scorce = model(iter(train_data).next()[0])
        print(scorce.shape[0], scorce.shape[1])
    if scorce.shape[0] == batch_size and scorce.shape[1] == 3:
        print('Model is ready!')
    else:
        print('Model is failed!')
except:
    print('model is wrong')

if use_gpu:
    model = model.cuda()
# Out:
# 10 3
# Model is ready!

# %%
# 构建loss函数和优化器
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4)

# 训练的epoches数目
max_epoch = 20

# %%
# 训练
def train(model, train_data, valid_data, max_epoch, criterion, optimizer):
    freq_print = int(len(train_data) / 3)
    
    metric_log = dict()
    metric_log['train_loss'] = list()
    metric_log['train_acc'] = list()
    if valid_data is not None:
        metric_log['valid_loss'] = list()
        metric_log['valid_acc'] = list()
    
    for e in range(max_epoch):
        model.train()
        running_loss = 0
        running_acc = 0

        for i, data in enumerate(train_data, 1):
            img, label = data
            if use_gpu:
                img = img.cuda()
                label = label.cuda()

            # forward前向传播
            out = model(img)

            # 计算误差
            loss = criterion(out, label.long())

            # 反向传播，更新参数
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # 计算准确率
            _, pred = out.max(1)
            num_correct = (pred == label.long()).sum().item()
            acc = num_correct/img.shape[0]

            running_loss += loss.item()
            running_acc +=acc

            if i % freq_print == 0:
                print('[{}]/[{}], train loss: {:.3f}, train acc: {:.3f}' \
                .format(i, len(train_data), running_loss / i, running_acc / i))
        
        metric_log['train_loss'].append(running_loss / len(train_data))
        metric_log['train_acc'].append(running_acc / len(train_data))

        if valid_data is not None:
            model.eval()
            running_loss = 0
            running_acc = 0
            for data in valid_data:
                img, label = data
                if use_gpu:
                    img = img.cuda()
                    label = label.cuda()
                
                # forward前向传播
                out = model(img)

                # 计算误差
                loss = criterion(out, label.long())

                # 计算准确度
                _, pred = out.max(1)
                num_correct = (pred==label.long()).sum().item()
                acc = num_correct/img.shape[0]


                running_loss += loss.item()
                running_acc += acc

            metric_log['valid_loss'].append(running_loss/len(valid_data))
            metric_log['valid_acc'].append(running_acc/len(valid_data))
            print_str = 'epoch: {}, train loss: {:.3f}, train acc: {:.3f}, \
            valid loss: {:.3f}, valid accuracy: {:.3f}'.format(
                        e+1, metric_log['train_loss'][-1], metric_log['train_acc'][-1],
                        metric_log['valid_loss'][-1], metric_log['valid_acc'][-1])
        else:
            print_str = 'epoch: {}, train loss: {:.3f}, train acc: {:.3f}'.format(
                e+1,
                metric_log['train_loss'][-1],
                metric_log['train_acc'][-1])
        print(print_str)

        
    # 可视化
    nrows = 1
    ncols = 2
    figsize= (10, 5)
    _, figs = plt.subplots(nrows, ncols, figsize=figsize)
    if valid_data is not None:
        figs[0].plot(metric_log['train_loss'], label='train loss')
        figs[0].plot(metric_log['valid_loss'], label='valid loss')
        figs[0].axes.set_xlabel('loss')
        figs[0].legend(loc='best')
        figs[1].plot(metric_log['train_acc'], label='train acc')
        figs[1].plot(metric_log['valid_acc'], label='valid acc')
        figs[1].axes.set_xlabel('acc')
        figs[1].legend(loc='best')
    else:
        figs[0].plot(metric_log['train_loss'], label='train loss')
        figs[0].axes.set_xlabel('loss')
        figs[0].legend(loc='best')
        figs[1].plot(metric_log['train_acc'], label='train acc')
        figs[1].axes.set_xlabel('acc')
        figs[1].legend(loc='best')

# %%
# 用作调参
train(model, train_data, valid_data, max_epoch, criterion, optimizer)
# Out:
# [16]/[49], train loss: 0.632, train acc: 0.738
# [32]/[49], train loss: 0.507, train acc: 0.797
# [48]/[49], train loss: 0.433, train acc: 0.829
# epoch: 1, train loss: 0.425, train acc: 0.833,             valid loss: 0.174, valid accuracy: 0.986
# [16]/[49], train loss: 0.134, train acc: 0.962
# [32]/[49], train loss: 0.186, train acc: 0.931
# [48]/[49], train loss: 0.197, train acc: 0.935
# epoch: 2, train loss: 0.197, train acc: 0.934,             valid loss: 0.204, valid accuracy: 0.957
# [16]/[49], train loss: 0.257, train acc: 0.894
# [32]/[49], train loss: 0.196, train acc: 0.916
# [48]/[49], train loss: 0.236, train acc: 0.908
# epoch: 3, train loss: 0.239, train acc: 0.906,             valid loss: 0.202, valid accuracy: 0.971
# [16]/[49], train loss: 0.179, train acc: 0.963
# [32]/[49], train loss: 0.221, train acc: 0.937
# [48]/[49], train loss: 0.261, train acc: 0.912
# epoch: 4, train loss: 0.257, train acc: 0.914,             valid loss: 0.196, valid accuracy: 0.943
# [16]/[49], train loss: 0.184, train acc: 0.944
# [32]/[49], train loss: 0.163, train acc: 0.944
# [48]/[49], train loss: 0.151, train acc: 0.944
# epoch: 5, train loss: 0.151, train acc: 0.945,             valid loss: 0.112, valid accuracy: 0.964
# [16]/[49], train loss: 0.084, train acc: 0.975
# [32]/[49], train loss: 0.129, train acc: 0.953
# [48]/[49], train loss: 0.139, train acc: 0.944
# epoch: 6, train loss: 0.136, train acc: 0.945,             valid loss: 0.228, valid accuracy: 0.929
# [16]/[49], train loss: 0.099, train acc: 0.969
# [32]/[49], train loss: 0.084, train acc: 0.975
# [48]/[49], train loss: 0.085, train acc: 0.973
# epoch: 7, train loss: 0.084, train acc: 0.973,             valid loss: 0.085, valid accuracy: 0.979
# [16]/[49], train loss: 0.081, train acc: 0.956
# [32]/[49], train loss: 0.083, train acc: 0.966
# [48]/[49], train loss: 0.087, train acc: 0.967
# epoch: 8, train loss: 0.086, train acc: 0.967,             valid loss: 0.132, valid accuracy: 0.950
# [16]/[49], train loss: 0.057, train acc: 0.994
# [32]/[49], train loss: 0.098, train acc: 0.969
# [48]/[49], train loss: 0.092, train acc: 0.967
# epoch: 9, train loss: 0.099, train acc: 0.965,             valid loss: 0.179, valid accuracy: 0.957
# [16]/[49], train loss: 0.060, train acc: 0.988
# [32]/[49], train loss: 0.080, train acc: 0.981
# [48]/[49], train loss: 0.136, train acc: 0.969
# epoch: 10, train loss: 0.134, train acc: 0.969,             valid loss: 0.235, valid accuracy: 0.857
# [16]/[49], train loss: 0.147, train acc: 0.956
# [32]/[49], train loss: 0.124, train acc: 0.959
# [48]/[49], train loss: 0.150, train acc: 0.952
# epoch: 11, train loss: 0.152, train acc: 0.951,             valid loss: 0.167, valid accuracy: 0.950
# [16]/[49], train loss: 0.201, train acc: 0.956
# [32]/[49], train loss: 0.150, train acc: 0.966
# [48]/[49], train loss: 0.144, train acc: 0.958
# epoch: 12, train loss: 0.141, train acc: 0.959,             valid loss: 0.261, valid accuracy: 0.921
# [16]/[49], train loss: 0.129, train acc: 0.956
# [32]/[49], train loss: 0.134, train acc: 0.956
# [48]/[49], train loss: 0.120, train acc: 0.954
# epoch: 13, train loss: 0.118, train acc: 0.955,             valid loss: 0.189, valid accuracy: 0.957
# [16]/[49], train loss: 0.096, train acc: 0.975
# [32]/[49], train loss: 0.090, train acc: 0.972
# [48]/[49], train loss: 0.098, train acc: 0.969
# epoch: 14, train loss: 0.096, train acc: 0.969,             valid loss: 0.242, valid accuracy: 0.936
# [16]/[49], train loss: 0.130, train acc: 0.925
# [32]/[49], train loss: 0.123, train acc: 0.937
# [48]/[49], train loss: 0.108, train acc: 0.946
# epoch: 15, train loss: 0.107, train acc: 0.947,             valid loss: 0.137, valid accuracy: 0.957
# [16]/[49], train loss: 0.048, train acc: 0.981
# [32]/[49], train loss: 0.073, train acc: 0.978
# [48]/[49], train loss: 0.079, train acc: 0.979
# epoch: 16, train loss: 0.077, train acc: 0.980,             valid loss: 0.152, valid accuracy: 0.936
# [16]/[49], train loss: 0.137, train acc: 0.956
# [32]/[49], train loss: 0.100, train acc: 0.966
# [48]/[49], train loss: 0.088, train acc: 0.971
# epoch: 17, train loss: 0.088, train acc: 0.971,             valid loss: 0.133, valid accuracy: 0.964
# [16]/[49], train loss: 0.111, train acc: 0.969
# [32]/[49], train loss: 0.088, train acc: 0.972
# [48]/[49], train loss: 0.102, train acc: 0.965
# epoch: 18, train loss: 0.103, train acc: 0.963,             valid loss: 0.211, valid accuracy: 0.921
# [16]/[49], train loss: 0.190, train acc: 0.944
# [32]/[49], train loss: 0.157, train acc: 0.950
# [48]/[49], train loss: 0.121, train acc: 0.962
# epoch: 19, train loss: 0.119, train acc: 0.963,             valid loss: 0.172, valid accuracy: 0.957
# [16]/[49], train loss: 0.051, train acc: 0.988
# [32]/[49], train loss: 0.068, train acc: 0.975
# [48]/[49], train loss: 0.062, train acc: 0.981
# epoch: 20, train loss: 0.061, train acc: 0.982,             valid loss: 0.291, valid accuracy: 0.871

# %%
# 保存模型
torch.save(model.state_dict(), './model/save_model.pth')
